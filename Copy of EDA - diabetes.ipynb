# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load the diabetes dataset
from sklearn.datasets import load_diabetes
diabetes_X,diabetes_y = load_diabetes(return_X_y = True)

# %%
# Using one feature from the data
diabetes_X = diabetes_X[:, np.newaxis, 2]

# %%
# Visualization
import matplotlib.pyplot as plt
plt.scatter(diabetes_X, diabetes_y, color="black")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.grid()
plt.show()

# %%
# Train and Test variables
diabetes_X_train = diabetes_X[:-20]
diabetes_X_test = diabetes_X[-20:]
diabetes_y_train = diabetes_y[:-20]
diabetes_y_test = diabetes_y[-20:]

# %%
# Running Linear REGRESSOR Algortihm
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
# Fit the model 
model.fit(diabetes_X_train, diabetes_y_train)
# Out:
# LinearRegression()

# %%
# Predict the output
diabetes_y_pred = model.predict(diabetes_X_test)
diabetes_y_pred
# Out:
# array([225.9732401 , 115.74763374, 163.27610621, 114.73638965,
#        120.80385422, 158.21988574, 236.08568105, 121.81509832,
#         99.56772822, 123.83758651, 204.73711411,  96.53399594,
#        154.17490936, 130.91629517,  83.3878227 , 171.36605897,
#        137.99500384, 137.99500384, 189.56845268,  84.3990668 ])

# %%
diabetes_y_test
# Out:
# array([233.,  91., 111., 152., 120.,  67., 310.,  94., 183.,  66., 173.,
#         72.,  49.,  64.,  48., 178., 104., 132., 220.,  57.])

# %%
#Cross verification
m = model.coef_
print("Coefficients: \n", model.coef_)
# Out:
# Coefficients:
#  [938.23786125]

# %%
C = model.intercept_
C
# Out:
# 152.91886182616167

# %%
m*2000 + C
# Out:
# array([1876628.64136435])

# %%
#VISUALIZATION for the best fit line
# Try 1
plt.scatter(diabetes_X_test,diabetes_y_test,c="green") #Actual values
plt.plot(diabetes_X_test,diabetes_y_test,c="Orange",linewidth=3)
plt.grid()
plt.show()

# %%
# Try 2
plt.scatter(diabetes_X_test, diabetes_y_test, color="black")
plt.plot(diabetes_X_test, diabetes_y_pred, color="blue", linewidth=3)
plt.xticks(())
plt.yticks(())
plt.show()
